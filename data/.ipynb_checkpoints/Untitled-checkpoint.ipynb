# %%
import json
import pandas as pd
from datetime import datetime
import os
import requests
from bs4 import BeautifulSoup
import time
from random import random

# %%
with open('first_100_rows.json') as f:
    reviews = []
    for row in f:
        reviews.append(json.loads(row))

# %%
goodreads_key = os.environ['GOODREADS_API_KEY']
goodreads_secret = os.environ['GOODREADS_SECRET']
aws_key = os.environ['AWS_ACCESS_KEY_ID']
aws_secret = os.environ['AWS_SECRET_ACCESS_KEY']

# %%
df = pd.DataFrame(reviews)

# %%
reviews

# %%
df

# %%
df['asin'][26]

# %%
with open('combined_lists.json') as f:
    contents = json.load(f)

# %%
contents

# %%
flat_data = []
for list_date, lst in contents.iteritems():
    for title, meta in lst.iteritems():
        d = meta.copy()
        d['title'] = title
        d['list_date'] = list_date
        flat_data.append(d)

# %%
books = pd.DataFrame(flat_data)
# books = pd.read_csv('combined_bestseller_lists.csv', index_col = 0)

# %%
books

# %%
# books.to_csv('combined_bestseller_lists.csv', encoding='utf-8')

# %%
books[books.isbn13.str.contains('B00LL0DR94')]

# %%
len(books.title.unique())

# %%
B00547KH66

# %%
# books[books.isbn13.str.contains('A00')]
books[books['isbn13'].str.contains("978")]

# %%
def get_isbns(books_df):
    for row in books_df.index:
        old_isbn10 = books.loc[row, 'isbn10']
        old_isbn13 = books.loc[row, 'isbn13']
        if old_isbn13.startswith('A00'):
            t = '+'.join(books.loc[row, 'title'].split())
            a = '+'.join(books.loc[row, 'author'].split())
#                 print t, a, row
            gr_isbn_url = 'https://www.goodreads.com/book/title.xml?author={}&key={}&title={}'.format(a, goodreads_key, t)
            gr_content = requests.get(gr_isbn_url)
            soup = BeautifulSoup(gr_content.content, "html.parser")
            try:
                new_isbn10 = soup.find('isbn').contents[0]
                new_isbn13 = soup.find('isbn13').contents[0]
                books_df.replace(to_replace = old_isbn10, value = new_isbn10, inplace = True)
                books_df.replace(to_replace = old_isbn13, value = new_isbn13, inplace = True)
            except AttributeError:
                new_isbn10 = old_isbn10
                new_isbn13 = old_isbn13

    return books_df

# %%
get_isbns(books)

# %%
books['isbn10'][2]

# %%
a = '+'.join('Chris Culver')
t = '+'.join('the abbey')
gr_isbn_url = 'https://www.goodreads.com/book/title.xml?author={}&key={}&title={}'.format(a, goodreads_key, t)
gr_content = requests.get(gr_isbn_url)
soup = BeautifulSoup(gr_content.content, "html.parser")
str(soup)

# %%
books.isbn13.replace(to_replace='A00B00547KH66', value='9780451198518', inplace = True)

# %%
t = '+'.join(books.)

# %%
'+'.join(books.loc[0, 'author'].split())

# %%
books_copied = books.copy()

# %%
books_copied.to_csv('books_copied.csv', encoding = 'utf-8')

# %%
sorted(books.list_date.unique())

# %%
one_list = books[books.list_date == '2011-02-26']

# %%
one_list

# %%
pwd
# Out:
# u'/Users/asalmitrofanov/DSI/fiction-market-analysis-capstone'

# %%
books = pd.read_csv('data/book_meta_with_isbns.tsv', delimiter = '\t')

# %%
missing_isbns = books[(books['isbn10'] == ' ') & (books['isbn13'] == ' ') ]['author_title']

# %%
missing_isbns = pd.DataFrame(np.unique(missing_isbns.values), columns = ['author_title'])

# %%
missing_isbns['isbn10'] = None
missing_isbns['isbn13'] = None

# %%
missing_isbns[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-493-cef5ec0f7018> in <module>()
# ----> 1 missing_isbns[:,:]
#
# /Users/asalmitrofanov/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Users/asalmitrofanov/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /Users/asalmitrofanov/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1346         """Return the cached item, item represents a label indexer."""
#    1347         cache = self._item_cache
# -> 1348         res = cache.get(item)
#    1349         if res is None:
#    1350             values = self._data.get(item)
#
# TypeError: unhashable type

# %%
def get_isbns_google(books):
    isbns = {}
    books_not_found = []
    for book in books:
#         print book
        t = '+'.join(book.split('**')[1].replace("'", '').encode('utf-8').split())
        a = '+'.join(book.split('**')[0].replace('.', '').encode('utf-8').split())
        ggl_url = "https://www.google.com/search?q={}+{}+isbn&oq={}+{}+isbn&aqs=chrome.\
                    .69i57.11282j0j8&sourceid=chrome&ie=UTF-8".format(t, a, t, a)
        ggl_cont = requests.get(ggl_url)
        soup = BeautifulSoup(ggl_cont.content, 'html.parser')
        try:
            isbn = soup.findAll("span", {"class": "_G0d"})[0].text
            if len(isbn) == 13:
                isbns[book] = {'isbn10' : None,
                               'isbn13' : isbn}
            elif len(isbn) == 10:
                isbns[book] = {'isbn10' : isbn,
                               'isbn13' : None}
            else:
                isbns[book] = {'isbn10' : None,
                               'isbn13' : None}
        except IndexError:
            books_not_found.append(book)
            isbns[book] = {'isbn10' : None,
                           'isbn13' : None}
        time.sleep(1 + random()*3)
    return isbns, books_not_found

# %%
isbns_found, still_missing = get_isbns_google(missing_isbns.author_title.values)

# %%
isbns = pd.DataFrame(isbns_found).T

# %%
isbns.reset_index(inplace = True)

# %%
google_isbns = isbns[isbns.isbn13.notnull()]

# %%
google_isbns.to_csv('data/google_isbns.tsv', sep = '\t')

# %%
pwd
# Out:
# u'/Users/asalmitrofanov/DSI/fiction-market-analysis-capstone'

# %%
different_format = []
no_list = []
parsed_pdf_flat_data = []
for list_date, lst in pdf_contents.iteritems():
    if lst == "This list is in a different format":
        different_format.append(list_date)
    elif lst == "No list on this date":
        no_list.append(list_date)
    else:
        for title, meta in lst.iteritems():
            d = meta.copy()
            d['title'] = title
            d['list_date'] = list_date
            parsed_pdf_flat_data.append(d)

# %%
# different_format

# %%
parsed_pdf_lists = pd.DataFrame(parsed_pdf_flat_data)

# %%
asins_df = parsed_pdf_lists.copy()

# %%
asins_df.insert(0, 'asin', None)

# %%
asins_df['author_title'] = asins_df.author + '**' + asins_df.title

# %%
asins_df.author_title.unique()

# %%
len(parsed_pdf_lists.list_date.unique())

# %%
def get_isbns_asins(books):
    scraped = {}
    for book in books:
        isbn10 = None
        isbn13 = None
        asin = None
        book = book.encode('utf-8')
        t = '+'.join(book.split('**')[1].split())
        a = '+'.join(book.split('**')[0].split())

        gr_isbn_url = 'https://www.goodreads.com/book/title.xml?author={}&key={}&title={}'.format(a, goodreads_key, t)
        gr_content = requests.get(gr_isbn_url)
        soup = BeautifulSoup(gr_content.content, "html.parser")
        try:
            isbn10 = soup.find('isbn').contents[0]
            isbn13 = soup.find('isbn13').contents[0]
            asin = soup.find('kindle_asin').contents[0]
        except AttributeError:
            continue
        except UnicodeEncodeError:
            continue
        scraped[book] = {'isbn10':isbn10, 'isbn13':isbn13, 'asin':asin}
        time.sleep(1 + random()*2)

    with open('data/format2_books_with_isbns_part3.json', mode='w') as f:
        f.write(json.dumps(scraped, indent=2))

# %%
get_isbns_asins(books)

# %%
books = asins_df.author_title.unique()
for book in books:
    print book

# %%
with open('data/books_with_isbns.json', mode='r') as f:
    book_data = json.load(f)

# %%
book_data

# %%
with open('data/parsed_pdf_lists_format2.json', 'r') as f:
    scraped_books_format2 = json.load(f)
#     scraped_books_format2 = []
#     for row in f: 
#         print row    
#         scraped_books_format2.append(json.loads(row))

# %%
scraped_books_format2
# Out:
# {u'1979-06-24': {u'9 Other Top-ranking NATO Generals and Advisors.': {u'asin': None,
#    u'author': u'9 Other Top-ranking NATO Generals and Advisors.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'9'},
#   u'CHESAPEAKE': {u'asin': None,
#    u'author': u' James A. Michener.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'11',
#    u'wks_on_list': u'45'},
#   u'CLASS REUNION': {u'asin': None,
#    u'author': u' Rona Jaffe.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'11',
#    u'rank_this_wk': u'14',
#    u'wks_on_list': u'5'},
#   u'GHOST STORY': {u'asin': None,
#    u'author': u' Peter Straub.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'12',
#    u'rank_this_wk': u'12',
#    u'wks_on_list': u'11'},
#   u'GOOD AS GOLD': {u'asin': None,
#    u'author': u' Joseph Heller.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'16'},
#   u'HANTA YO': {u'asin': None,
#    u'author': u' Ruth Beebe Hill.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'19'},
#   u'SHIBUMI': {u'asin': None,
#    u'author': u' Trevanian.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'8'},
#   u"SOPHIE'S CHOICE": {u'asin': None,
#    u'author': u' William Styron.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'3'},
#   u'SPHINX': {u'asin': None,
#    u'author': u' Robin Cook.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'13',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'2'},
#   u'SS-GB': {u'asin': None,
#    u'author': u' Len Deighton.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'13',
#    u'wks_on_list': u'15'},
#   u'THE ISLAND': {u'asin': None,
#    u'author': u' Peter Benchley.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'4'},
#   u'THE MATARESE CIRCLE': {u'asin': None,
#    u'author': u' Robert Ludlum.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'16'},
#   u'THE VICAR OF CHRIST': {u'asin': None,
#    u'author': u' Walter F. Murphy.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'15',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'8'},
#   u"THERE'S NO SUCH PLACE AS FAR AWAY": {u'asin': None,
#    u'author': u' Richard Bach.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'15',
#    u'wks_on_list': u'3'},
#   u'WAR AND REMEMBRANCE': {u'asin': None,
#    u'author': u' Herman Wouk.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'38'}},
#  u'1994-03-27': {u'RIVER GOD': {u'asin': None,
#    u'author': u' Wilbur Smith.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'11',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'2'}},
#  u'1994-03-20': {u'FAMILY BLESSINGS': {u'asin': None,
#    u'author': u' LaVyrle Spencer.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'8'}},
#  u'1997-07-13': {u'CHASING CEZANNE': {u'asin': None,
#    u'author': u' Peter Mayle.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'5'},
#   u'COLD MOUNTAIN': {u'asin': None,
#    u'author': u' Charles Frazier.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'3'},
#   u'DECEPTION ON HIS MIND': {u'asin': None,
#    u'author': u' Elizabeth George.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'15',
#    u'rank_this_wk': u'12',
#    u'wks_on_list': u'2'},
#   u'FAT TUESDAY': {u'asin': None,
#    u'author': u' Sandra Brown.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'5'},
#   u'FATAL TERRAIN': {u'asin': None,
#    u'author': u' Dale Brown.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'15',
#    u'wks_on_list': u'1'},
#   u'LONDON': {u'asin': None,
#    u'author': u' Edward Rutherfurd.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'8'},
#   u'PLUM ISLAND': {u'asin': None,
#    u'author': u' Nelson DeMille.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'8'},
#   u'POWER OF A WOMAN': {u'asin': None,
#    u'author': u' Barbara Taylor Bradford.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'16',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'2'},
#   u"PRETEND YOU DON'T SEE HER": {u'asin': None,
#    u'author': u' Mary Higgins Clark.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'11',
#    u'rank_this_wk': u'14',
#    u'wks_on_list': u'14'},
#   u'SPECIAL DELIVERY': {u'asin': None,
#    u'author': u' Danielle Steel.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'1'},
#   u'THE MAZE': {u'asin': None,
#    u'author': u' Catherine Coulter.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'13',
#    u'rank_this_wk': u'11',
#    u'wks_on_list': u'2'},
#   u'THE NOTEBOOK': {u'asin': None,
#    u'author': u' Nicholas Sparks.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'40'},
#   u'THE PARTNER': {u'asin': None,
#    u'author': u' John Grisham.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'20',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'5'},
#   u"THE PRESIDENT'S DAUGHTER": {u'asin': None,
#    u'author': u' Jack Higgins.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'13',
#    u'wks_on_list': u'8'},
#   u'UP ISLAND': {u'asin': None,
#    u'author': u' Anne Rivers Siddons.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'7'}},
#  u'1975-04-13': {u'': {u'asin': None,
#    u'author': u'',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'21'},
#   u'A MONTH OF SUNDAYS': {u'asin': None,
#    u'author': u' John Updike.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'6'},
#   u'BLACK SUNDAY': {u'asin': None,
#    u'author': u' Thomas Harris',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'8'},
#   u'SOMETHING HAPPENED': {u'asin': None,
#    u'author': u' Joseph Heller.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'27'},
#   u'SPINDRIFT': {u'asin': None,
#    u'author': u' Phyllis A. Whitney.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'1'},
#   u'THE DREADFUL LEMON SKY': {u'asin': None,
#    u'author': u'MacDonald.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'6'},
#   u'THE MONEYCHANGERS': {u'asin': None,
#    u'author': u' Arthur Hailey.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'5'},
#   u'THE PROMISE OF JOY': {u'asin': None,
#    u'author': u' Allen Drury.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'5'}},
#  u'1989-09-17': {u'': {u'asin': None,
#    u'author': u'',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1897',
#    u'rank_this_wk': u'14',
#    u'wks_on_list': u'13'},
#   u'3': {u'asin': None,
#    u'author': u'3',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'3'},
#   u'BLESSINGS': {u'asin': None,
#    u'author': u' Belva Plain.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'11',
#    u'rank_this_wk': u'12',
#    u'wks_on_list': u'9'},
#   u'CALIFORNIA GOLD': {u'asin': None,
#    u'author': u' John Jakes.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'3'},
#   u'CLEAR AND PRESENT DANGER': {u'asin': None,
#    u'author': u' Tom Clancy.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'5'},
#   u'JOSHUA AND THE CHILDREN': {u'asin': None,
#    u'author': u' Joseph F. Girzone.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'7'},
#   u'KNIGHT IN SHINING ARMOR': {u'asin': None,
#    u'author': u' Jude Deveraux.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'12',
#    u'rank_this_wk': u'11',
#    u'wks_on_list': u'8'},
#   u'PILLARS OF THE EARTH': {u'asin': None,
#    u'author': u' Ken Follett.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'3'},
#   u'POLAR STAR': {u'asin': None,
#    u'author': u' Martin Cruz Smith.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'13'},
#   u'SILENT PARTNER': {u'asin': None,
#    u'author': u' Jonathan Kellerman.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1897',
#    u'rank_this_wk': u'13',
#    u'wks_on_list': u'0'},
#   u'THE JOY LUCK CLUB': {u'asin': None,
#    u'author': u' Amy Tan.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'26'},
#   u'THE OLD SILENT': {u'asin': None,
#    u'author': u' Martha Grimes.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'5'},
#   u'THE RUSSIA HOUSE': {u'asin': None,
#    u'author': u' John le Carr\xe9.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'17',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'6'},
#   u'WHILE MY PRETTY ONE SLEEPS': {u'asin': None,
#    u'author': u' Mary Higgins Clark.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'14',
#    u'rank_this_wk': u'15',
#    u'wks_on_list': u'21'}},
#  u'1989-09-10': {u'': {u'asin': None,
#    u'author': u'',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1897',
#    u'rank_this_wk': u'13',
#    u'wks_on_list': u'10'},
#   u'2': {u'asin': None,
#    u'author': u'2',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'2'},
#   u'BLESSINGS': {u'asin': None,
#    u'author': u' Belva Plain.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'11',
#    u'wks_on_list': u'8'},
#   u'CALIFORNIA GOLD': {u'asin': None,
#    u'author': u' John Jakes.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'12',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'2'},
#   u'CLEAR AND PRESENT DANGER': {u'asin': None,
#    u'author': u' Tom Clancy.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'4'},
#   u'JOSHUA AND THE CHILDREN': {u'asin': None,
#    u'author': u' Joseph F. Girzone.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'6'},
#   u'KNIGHT IN SHINING ARMOR': {u'asin': None,
#    u'author': u' Jude Deveraux.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'12',
#    u'wks_on_list': u'7'},
#   u'POLAR STAR': {u'asin': None,
#    u'author': u' Martin Cruz Smith.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'12'},
#   u'THE JOY LUCK CLUB': {u'asin': None,
#    u'author': u' Amy Tan.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'25'},
#   u'THE OLD SILENT': {u'asin': None,
#    u'author': u' Martha Grimes.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'4'},
#   u'THE PILLARS OF THE EARTH': {u'asin': None,
#    u'author': u' Ken Follett.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'13',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'2'},
#   u'THE RUSSIA HOUSE': {u'asin': None,
#    u'author': u' John le Carr\xe9.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'16'},
#   u'THE TEMPLE OF MY FAMILIAR': {u'asin': None,
#    u'author': u' Alice Walker.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'15',
#    u'rank_this_wk': u'15',
#    u'wks_on_list': u'21'},
#   u'WHILE MY PRETTY ONE SLEEPS': {u'asin': None,
#    u'author': u' Mary Higgins Clark.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'11',
#    u'rank_this_wk': u'14',
#    u'wks_on_list': u'20'}},
#  u'2000-06-18': {u'EASY PREY': {u'asin': None,
#    u'author': u' John Sandford.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'6'}},
#  u'2004-05-23': {u'GLORIOUS APPEARING': {u'asin': None,
#    u'author': u' Tim LaHaye and Jerry B. Jenkins.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'7'}},
#  u'1989-06-04': {u'A PRAYER FOR OWEN MEANY': {u'asin': None,
#    u'author': u' John Irving.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'12',
#    u'rank_this_wk': u'11',
#    u'wks_on_list': u'13'},
#   u'CAPITAL CRIMES': {u'asin': None,
#    u'author': u' Lawrence Sanders.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'3'},
#   u'GARDEN OF LIES': {u'asin': None,
#    u'author': u' Eileen Goudge.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'13',
#    u'rank_this_wk': u'15',
#    u'wks_on_list': u'2'},
#   u'PLAYMATES': {u'asin': None,
#    u'author': u' Robert B. Parker.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'5'},
#   u'RED PHOENIX': {u'asin': None,
#    u'author': u' Larry Bond.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'11',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'3'},
#   u'STAR': {u'asin': None,
#    u'author': u' Danielle Steel.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'14',
#    u'wks_on_list': u'16'},
#   u'STRANGER IN SAVANNAH': {u'asin': None,
#    u'author': u' Eugenia Price.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'12',
#    u'wks_on_list': u'6'},
#   u'TALKING GOD': {u'asin': None,
#    u'author': u' Tony Hillerman.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'3'},
#   u'THE JOY LUCK CLUB': {u'asin': None,
#    u'author': u' Amy Tan.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'11'},
#   u'THE NEGOTIATOR': {u'asin': None,
#    u'author': u' Frederick Forsyth.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'8'},
#   u'THE RUSSIA HOUSE': {u'asin': None,
#    u'author': u' John le Carr\xe9.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'1'},
#   u'THE SATANIC VERSES': {u'asin': None,
#    u'author': u' Salman Rushdie.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'16'},
#   u'THE TEMPLE OF MY FAMILIAR': {u'asin': None,
#    u'author': u' Alice Walker.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'7'},
#   u'WE ARE STILL MARRIED': {u'asin': None,
#    u'author': u' Garrison Keillor.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'14',
#    u'rank_this_wk': u'13',
#    u'wks_on_list': u'11'},
#   u'WHILE MY PRETTY ONE SLEEPS': {u'asin': None,
#    u'author': u' Mary Higgins Clark.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'6'}},
#  u'1997-03-23': {u'A THIN DARK LINE': {u'asin': None,
#    u'author': u' Tami Hoag.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'3'}},
#  u'1978-07-09': {u'BLOODLINE': {u'asin': None,
#    u'author': u' Sidney Sheldon.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'24'},
#   u'CHESAPEAKE': {u'asin': None,
#    u'author': u' James A. Michener.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'1'},
#   u'EVERGREEN': {u'asin': None,
#    u'author': u' Belva Plain.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'11',
#    u'rank_this_wk': u'12',
#    u'wks_on_list': u'4'},
#   u'EYE OF THE NEEDLE': {u'asin': None,
#    u'author': u' Ken Follett.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'14',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'3'},
#   u'FINAL PAYMENTS': {u'asin': None,
#    u'author': u' Mary Gordon.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'15',
#    u'wks_on_list': u'15'},
#   u'ILLUSIONS': {u'asin': None,
#    u'author': u' Richard Bach.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'58'},
#   u'MORTAL FRIENDS': {u'asin': None,
#    u'author': u' James Carroll.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'14',
#    u'wks_on_list': u'4'},
#   u'SCRUPLES': {u'asin': None,
#    u'author': u' Judith Krantz.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'20'},
#   u'STAINED GLASS': {u'asin': None,
#    u'author': u' William F. Buckley Jr.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'9'},
#   u'THE HOLCROFT COVENANT': {u'asin': None,
#    u'author': u' Robert Ludlum.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'16'},
#   u'THE HUMAN FACTOR': {u'asin': None,
#    u'author': u' Graham Greene.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'11',
#    u'wks_on_list': u'18'},
#   u'THE LAST CONVERTIBLE': {u'asin': None,
#    u'author': u' Anton Myrer.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'7'},
#   u'THE SILMARILLION': {u'asin': None,
#    u'author': u' J.R.R. Tolkien.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'13',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'44'},
#   u"THE WOMEN'S ROOM": {u'asin': None,
#    u'author': u' Marilyn French.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'13',
#    u'wks_on_list': u'33'},
#   u'THE WORLD ACCORDING TO GARP': {u'asin': None,
#    u'author': u' John Irving.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'9'}},
#  u'2000-06-11': {u'THE BLUEST EYE': {u'asin': None,
#    u'author': u' Toni Morrison.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'0'}},
#  u'1978-07-02': {u'BLOODLINE': {u'asin': None,
#    u'author': u' Sidney Sheldon.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'23'},
#   u'EVERGREEN': {u'asin': None,
#    u'author': u' Belva Plain.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'15',
#    u'rank_this_wk': u'11',
#    u'wks_on_list': u'3'},
#   u'EYE OF THE NEEDLE': {u'asin': None,
#    u'author': u' Ken Follett.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'13',
#    u'rank_this_wk': u'14',
#    u'wks_on_list': u'2'},
#   u'FINAL PAYMENTS': {u'asin': None,
#    u'author': u' Mary Gordon.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'15',
#    u'wks_on_list': u'3'},
#   u'ILLUSIONS': {u'asin': None,
#    u'author': u' Richard Bach.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'57'},
#   u'KALKI': {u'asin': None,
#    u'author': u' Gore Vidal.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'12',
#    u'rank_this_wk': u'12',
#    u'wks_on_list': u'8'},
#   u'MORTAL FRIENDS': {u'asin': None,
#    u'author': u' James Carroll.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'11',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'3'},
#   u'SCRUPLES': {u'asin': None,
#    u'author': u' Judith Krantz.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'19'},
#   u'STAINED GLASS': {u'asin': None,
#    u'author': u' William F. Buckley Jr.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'8'},
#   u'THE HOLCROFT COVENANT': {u'asin': None,
#    u'author': u' Robert Ludlum.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'15'},
#   u'THE HUMAN FACTOR': {u'asin': None,
#    u'author': u' Graham Greene.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'17'},
#   u'THE LAST CONVERTIBLE': {u'asin': None,
#    u'author': u' Anton Myrer.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'7'},
#   u'THE SILMARILLION': {u'asin': None,
#    u'author': u' J.R.R. Tolkien.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'13',
#    u'wks_on_list': u'43'},
#   u"THE WOMEN'S ROOM": {u'asin': None,
#    u'author': u' Marilyn French.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'32'},
#   u'THE WORLD ACCORDING TO GARP': {u'asin': None,
#    u'author': u' John Irving.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'8'}},
#  u'1976-03-28': {u'1876': {u'asin': None,
#    u'author': u' Gore Vidal.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'1'},
#   u'CURTAIN': {u'asin': None,
#    u'author': u' Agatha Christie.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'28'},
#   u'RAGTIME': {u'asin': None,
#    u'author': u' E. L. Doctorow.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'37'},
#   u'SAVING THE QUEEN': {u'asin': None,
#    u'author': u'Jr.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'10'},
#   u'THE BOYS FROM BRAZIL': {u'asin': None,
#    u'author': u' Ira Levin.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'4'},
#   u'THE CHOIRBOYS': {u'asin': None,
#    u'author': u' Joseph Wambaugh.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'20'},
#   u'THE GEMINI CONTENDERS': {u'asin': None,
#    u'author': u' Robert Ludlum.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'4'},
#   u'THE GREEK TREASURE': {u'asin': None,
#    u'author': u' Irving Stone.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'24'},
#   u'THE R DOCUMENT': {u'asin': None,
#    u'author': u' Irving Wallace.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'1'},
#   u'TRINITY': {u'asin': None,
#    u'author': u' Leon Uris.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'3'}},
#  u'1986-07-06': {u'A MATTER OF HONOR': {u'asin': None,
#    u'author': u' Jeffrey Archer.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'3'},
#   u'A PERFECT SPY': {u'asin': None,
#    u'author': u' John le Carr\xe9.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'13'},
#   u'ACT OF WILL': {u'asin': None,
#    u'author': u' Barbara Taylor Bradford.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'5'},
#   u'BARRIER ISLAND': {u'asin': None,
#    u'author': u' John D. MacDonald.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'13',
#    u'rank_this_wk': u'13',
#    u'wks_on_list': u'5'},
#   u'GONE WITH THE WIND': {u'asin': None,
#    u'author': u' Margaret Mitchell.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'11',
#    u'wks_on_list': u'5'},
#   u"I'LL TAKE MANHATTAN": {u'asin': None,
#    u'author': u' Judith Krantz.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'13'},
#   u'LAKE WOBEGON DAYS': {u'asin': None,
#    u'author': u' Garrison Keillor.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'12',
#    u'rank_this_wk': u'12',
#    u'wks_on_list': u'47'},
#   u'LAST OF THE BREED': {u'asin': None,
#    u'author': u" Louis L'Amour.",
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'6'},
#   u'TAMING A SEA-HORSE': {u'asin': None,
#    u'author': u' Robert B. Parker.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'11',
#    u'rank_this_wk': u'14',
#    u'wks_on_list': u'6'},
#   u'THE BOURNE SUPREMACY': {u'asin': None,
#    u'author': u' Robert Ludlum.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'20'},
#   u'THE EIGHTH COMMANDMENT': {u'asin': None,
#    u'author': u' Lawrence Sanders.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'7'},
#   u'THE GARDEN OF EDEN': {u'asin': None,
#    u'author': u' Ernest Hemingway.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'8'},
#   u'THE GOOD MOTHER': {u'asin': None,
#    u'author': u' Sue Miller.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'10'},
#   u'THE MAMMOTH HUNTERS': {u'asin': None,
#    u'author': u' Jean M. Auel.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'14',
#    u'rank_this_wk': u'15',
#    u'wks_on_list': u'35'},
#   u'WANDERLUST': {u'asin': None,
#    u'author': u' Danielle Steel.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'1'}},
#  u'1976-03-21': {u'1876': {u'asin': None,
#    u'author': u' Gore Vidal.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'3'},
#   u'CURTAIN': {u'asin': None,
#    u'author': u' Agatha Christie.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'27',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'1'},
#   u'IN THE BEGINNING': {u'asin': None,
#    u'author': u' Chaim Potok.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'20'},
#   u'NIGHTWORK': {u'asin': None,
#    u'author': u' Irwin Shaw.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'14'},
#   u'RAGTIME': {u'asin': None,
#    u'author': u' E. L. Doctorow.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'36'},
#   u'SAVING THE QUEEN': {u'asin': None,
#    u'author': u'Jr.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'9'},
#   u'THE BOYS FROM BRAZIL': {u'asin': None,
#    u'author': u' Ira Levin.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'3'},
#   u'THE CHOIRBOYS': {u'asin': None,
#    u'author': u' Joseph Wambaugh.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'19'},
#   u'THE GEMINI CONTENDERS': {u'asin': None,
#    u'author': u' Robert Ludlum.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'3'},
#   u'TRINITY': {u'asin': None,
#    u'author': u' Leon Uris.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'2'}},
#  u'1974-05-05': {u'BURR': {u'asin': None,
#    u'author': u' Gore Vidal.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'27'},
#   u'COME NINEVEH': {u'asin': None,
#    u'author': u' Allen Drury.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'26'},
#   u'I HEARD THE OWL CALL MY NAME': {u'asin': None,
#    u'author': u' Margaret Craven.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'7'},
#   u'JAWS': {u'asin': None,
#    u'author': u'Peter Benchley.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'11'},
#   u'THE FAN CLUB': {u'asin': None,
#    u'author': u' Irving Wallace.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'5'},
#   u'THE PARTNERS': {u'asin': None,
#    u'author': u' Louis Auchincloss.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'9'},
#   u'THE SNARE OF THE HUNTER': {u'asin': None,
#    u'author': u' Helen MacInnes.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'11'},
#   u'TUESDAY THE RABBI SAW RED': {u'asin': None,
#    u'author': u' Harry Kemelman.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'6'},
#   u'YOU AND ME BABE': {u'asin': None,
#    u'author': u' Chuck Barris.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'3'},
#   u'by Richard Adams.': {u'asin': None,
#    u'author': u' Richard Adams.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'6'}},
#  u'1975-08-10': {u'': {u'asin': None,
#    u'author': u'',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'52'},
#   u'LOOKING FOR MR. GOODBAR': {u'asin': None,
#    u'author': u' Judith Rossner.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'10'},
#   u'RAGTIME': {u'asin': None,
#    u'author': u' E. L. Doctorow.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'1'},
#   u'SHARDIK': {u'asin': None,
#    u'author': u' Richard Adams.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'15'},
#   u'SHOGUN': {u'asin': None,
#    u'author': u' James Clavell.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'6'},
#   u'THE BOAT': {u'asin': None,
#    u'author': u' Lothar-Guenther Buchheim.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'3'},
#   u'THE DREADFUL LEMON SKY': {u'asin': None,
#    u'author': u'MacDonald.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'23'},
#   u'THE EAGLE HAS LANDED': {u'asin': None,
#    u'author': u' Jack Higgins.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'3'},
#   u'THE GREAT TRAIN ROBBERY': {u'asin': None,
#    u'author': u'',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'9'},
#   u'THE MONEYCHANGERS': {u'asin': None,
#    u'author': u' Arthur Hailey.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'22'}},
#  u'1975-08-17': {u'': {u'asin': None,
#    u'author': u'',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'53'},
#   u'CIRCUS': {u'asin': None,
#    u'author': u' Alistair MacLean.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'1'},
#   u'LOOKING FOR MR. GOODBAR': {u'asin': None,
#    u'author': u' Judith Rossner.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'11'},
#   u'RAGTIME': {u'asin': None,
#    u'author': u' E. L. Doctorow.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'1'},
#   u'SHARDIK': {u'asin': None,
#    u'author': u' Richard Adams.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'16'},
#   u'SHOGUN': {u'asin': None,
#    u'author': u' James Clavell.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'7'},
#   u'THE BOAT': {u'asin': None,
#    u'author': u' Lothar-Gunther Buchheim.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'10'},
#   u'THE EAGLE HAS LANDED': {u'asin': None,
#    u'author': u' Jack Higgins.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'4'},
#   u'THE GREAT TRAIN ROBBERY': {u'asin': None,
#    u'author': u'',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'10'},
#   u'THE MONEYCHANGERS': {u'asin': None,
#    u'author': u' Arthur Hailey.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'23'}},
#  u'1976-08-08': {u'1876': {u'asin': None,
#    u'author': u' Gore Vidal.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'23'},
#   u'A STRANGER IN THE MIRROR': {u'asin': None,
#    u'author': u' Sidney Sheldon.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'17'},
#   u'AGENT IN PLACE': {u'asin': None,
#    u'author': u' Helen MacInnes.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'15'},
#   u'CROWNED HEADS': {u'asin': None,
#    u'author': u' Thomas Tryon.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'7'},
#   u'DOLORES': {u'asin': None,
#    u'author': u' Jacqueline Susann.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'6'},
#   u'THE DEEP': {u'asin': None,
#    u'author': u' Peter Benchley.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'13'},
#   u'THE LONELY LADY': {u'asin': None,
#    u'author': u' Harold Robbins.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'12'},
#   u'THE WEST END HORROR': {u'asin': None,
#    u'author': u' Nicholas Meyer.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'11'},
#   u'TOUCH NOT THE CAT': {u'asin': None,
#    u'author': u' Mary Stewart.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'3'},
#   u'TRINITY': {u'asin': None,
#    u'author': u' Leon Uris.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'22'}},
#  u'1988-06-05': {u'CRIMSON JOY': {u'asin': None,
#    u'author': u' Robert B. Parker.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'6'},
#   u'FREAKY DEAKY': {u'asin': None,
#    u'author': u' Elmore Leonard.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'5'},
#   u'INHERITANCE': {u'asin': None,
#    u'author': u' Judith Michael.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'14',
#    u'rank_this_wk': u'15',
#    u'wks_on_list': u'14'},
#   u'LOVE IN THE TIME OF CHOLERA': {u'asin': None,
#    u'author': u' Gabriel Garcia Marquez.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'9'},
#   u'PEOPLE LIKE US': {u'asin': None,
#    u'author': u' Dominick Dunne.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'6'},
#   u'PRELUDE TO FOUNDATION': {u'asin': None,
#    u'author': u' Isaac Asimov.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'13',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'5'},
#   u"QUINN'S BOOK": {u'asin': None,
#    u'author': u' William Kennedy.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'13',
#    u'wks_on_list': u'1'},
#   u'ROCK STAR': {u'asin': None,
#    u'author': u' Jackie Collins.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'9'},
#   u'SCORPIUS': {u'asin': None,
#    u'author': u' John Gardner.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'11',
#    u'rank_this_wk': u'12',
#    u'wks_on_list': u'4'},
#   u'TAPESTRY': {u'asin': None,
#    u'author': u' Belva Plain.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'14',
#    u'wks_on_list': u'7'},
#   u'THE BONFIRE OF THE VANITIES': {u'asin': None,
#    u'author': u' Tom Wolfe.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'33'},
#   u'THE ICARUS AGENDA': {u'asin': None,
#    u'author': u' Robert Ludlum.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'15'},
#   u'THE SHELL SEEKERS': {u'asin': None,
#    u'author': u' Rosamunde Pilcher.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'11',
#    u'wks_on_list': u'18'},
#   u'TREASURE': {u'asin': None,
#    u'author': u' Clive Cussler.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'12',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'14'},
#   u'ZOYA': {u'asin': None,
#    u'author': u' Danielle Steel.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'6'}},
#  u'1993-03-14': {u"THE DEVIL'S HEART": {u'asin': None,
#    u'author': u' Carmen Carter.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'1'}},
#  u'1975-12-14': {u'CURTAIN': {u'asin': None,
#    u'author': u' Agatha Christie.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'13',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'1'},
#   u"HUMBOLDT'S GIFT": {u'asin': None,
#    u'author': u' Saul Bellow.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'17'},
#   u'IN THE BEGINNING': {u'asin': None,
#    u'author': u' Chaim Potok.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'6'},
#   u'LOOKING FOR MR. GOODBAR': {u'asin': None,
#    u'author': u' Judith Rossner.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'28'},
#   u'NIGHTWORK': {u'asin': None,
#    u'author': u' Irwin Shaw.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'10'},
#   u'RAGTIME': {u'asin': None,
#    u'author': u' E. L. Doctorow.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'22'},
#   u'SHOGUN': {u'asin': None,
#    u'author': u' James Clavell.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'24'},
#   u'THE CHOIRBOYS': {u'asin': None,
#    u'author': u' Joseph Wambaugh.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'5'},
#   u'THE EAGLE HAS LANDED': {u'asin': None,
#    u'author': u' Jack Higgins.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'21'},
#   u'THE GREEK TREASURE': {u'asin': None,
#    u'author': u' Irving Stone.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'10'}},
#  u'1986-03-30': {u'': {u'asin': None,
#    u'author': u'',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'15',
#    u'wks_on_list': u'1'},
#   u'4': {u'asin': None,
#    u'author': u'4',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'4'},
#   u'BLACK GENESIS': {u'asin': None,
#    u'author': u' L. Ron Hubbard.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'14',
#    u'rank_this_wk': u'16',
#    u'wks_on_list': u'2'},
#   u'BREAK IN': {u'asin': None,
#    u'author': u' Dick Francis.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'4'},
#   u'CYCLOPS': {u'asin': None,
#    u'author': u' Clive Cussler.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'13',
#    u'rank_this_wk': u'13',
#    u'wks_on_list': u'12'},
#   u'HOME FRONT': {u'asin': None,
#    u'author': u' Patti Davis with Maureen Strange Foster.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'3'},
#   u'LAKE WOBEGON DAYS': {u'asin': None,
#    u'author': u' Garrison Keillor.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'33'},
#   u'LIE DOWN WITH LIONS': {u'asin': None,
#    u'author': u' Ken Follett.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'11'},
#   u"NERILKA'S STORY": {u'asin': None,
#    u'author': u' Anne McCaffrey.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'11',
#    u'rank_this_wk': u'12',
#    u'wks_on_list': u'2'},
#   u'PRIVATE AFFAIRS': {u'asin': None,
#    u'author': u' Judith Michael.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'7'},
#   u'SEASONS OF THE HEART': {u'asin': None,
#    u'author': u' Cynthia Freeman.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'3'},
#   u'STONE 588': {u'asin': None,
#    u'author': u' Gerald A. Browne.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'16',
#    u'rank_this_wk': u'14',
#    u'wks_on_list': u'10'},
#   u'TEXAS': {u'asin': None,
#    u'author': u' James A. Michener.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'12',
#    u'rank_this_wk': u'11',
#    u'wks_on_list': u'27'},
#   u'THE BOURNE SUPREMACY': {u'asin': None,
#    u'author': u' Robert Ludlum.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'6'},
#   u"THE HANDMAID'S TALE": {u'asin': None,
#    u'author': u' Margaret Atwood.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'7'},
#   u'THE MAMMOTH HUNTERS': {u'asin': None,
#    u'author': u' Jean M. Auel.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'21'}},
#  u'1979-01-14': {u'BRIGHT FLOWS THE RIVER': {u'asin': None,
#    u'author': u' Taylor Caldwell.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'12'},
#   u'CHESAPEAKE': {u'asin': None,
#    u'author': u' James A. Michener.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'22'},
#   u'EVERGREEN': {u'asin': None,
#    u'author': u' Belva Plain.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'25'},
#   u'FOOLS DIE': {u'asin': None,
#    u'author': u' Mario Puzo.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'17'},
#   u'ILLUSIONS': {u'asin': None,
#    u'author': u' Richard Bach.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'13',
#    u'wks_on_list': u'79'},
#   u'OVERLOAD': {u'asin': None,
#    u'author': u' Arthur Hailey.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'1'},
#   u'SECOND GENERATION': {u'asin': None,
#    u'author': u' Howard Fast.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'17'},
#   u'THE COUP': {u'asin': None,
#    u'author': u' John Updike.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'11',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'4'},
#   u'THE EMPTY COPPER SEA': {u'asin': None,
#    u'author': u' John D. MacDonald.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'12',
#    u'wks_on_list': u'13'},
#   u'THE FAR PAVILIONS': {u'asin': None,
#    u'author': u' M.M. Kaye.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'11',
#    u'wks_on_list': u'17'},
#   u'THE PRAISE SINGER': {u'asin': None,
#    u'author': u' Mary Renault.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'14',
#    u'wks_on_list': u'3'},
#   u'THE SILMARILLION': {u'asin': None,
#    u'author': u' J.R.R. Tolkien.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'62'},
#   u'THE SIXTH COMMANDMENT': {u'asin': None,
#    u'author': u' Lawrence Sanders.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'15',
#    u'wks_on_list': u'1'},
#   u'THE STORIES OF JOHN CHEEVER': {u'asin': None,
#    u'author': u' John Cheever.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'6'},
#   u'WAR AND REMEMBRANCE': {u'asin': None,
#    u'author': u' Herman Wouk.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'15'}},
#  u'1991-10-27': {u'REMEMBER': {u'asin': None,
#    u'author': u' Barbara Taylor Bradford.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'2'}},
# ...
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'13'},
#   u'THE LITTLE DRUMMER GIRL': {u'asin': None,
#    u'author': u' John le Carr\xe9.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'25'},
#   u'THE NAME OF THE ROSE': {u'asin': None,
#    u'author': u' Umberto Eco.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'11'},
#   u'THE SEDUCTION OF PETER S.': {u'asin': None,
#    u'author': u' Lawrence Sanders.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'7'},
#   u'THE SUMMER OF KATYA': {u'asin': None,
#    u'author': u' Trevanian.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'11',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'17'},
#   u'VOICE OF THE HEART': {u'asin': None,
#    u'author': u' Barbara Taylor Bradford.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'13',
#    u'rank_this_wk': u'14',
#    u'wks_on_list': u'23'},
#   u'WHITE GOLD WIELDER': {u'asin': None,
#    u'author': u' Stephen R. Donaldson.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'13',
#    u'wks_on_list': u'22'}},
#  u'1996-07-14': {u'THE WEDDING': {u'asin': None,
#    u'author': u' Julie Garwood.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'1'}},
#  u'1974-08-25': {u'': {u'asin': None,
#    u'author': u'',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'7'},
#   u'CASHELMARA': {u'asin': None,
#    u'author': u' Susan Howatch.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'16'},
#   u'JAWS': {u'asin': None,
#    u'author': u'Peter Benchley.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'27'},
#   u'THE DOGS OF WAR': {u'asin': None,
#    u'author': u' Frederick Forsyth.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'9'},
#   u'THE FAN CLUB': {u'asin': None,
#    u'author': u' Irving Wallace.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'21'},
#   u'THE HOUSE OF A THOUSAND LANTERNS': {u'asin': None,
#    u'author': u' Victoria Holt.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'4'},
#   u'THE WAR BETWEEN THE TATES': {u'asin': None,
#    u'author': u' Alison Lurie.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'2'},
#   u'TINKER': {u'asin': None,
#    u'author': u' John le Carr\xe9.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'12'},
#   u'WINTER KILLS': {u'asin': None,
#    u'author': u' Richard Condon.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'8'},
#   u'by Richard Adams.': {u'asin': None,
#    u'author': u' Richard Adams.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'22'}},
#  u'1989-03-19': {u'A PRAYER FOR OWEN MEANY': {u'asin': None,
#    u'author': u' John Irving.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'2'},
#   u'BILLY BATHGATE': {u'asin': None,
#    u'author': u' E. L. Doctorow.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'5'},
#   u'BLACK SAND': {u'asin': None,
#    u'author': u' William J. Caunitz.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'12',
#    u'wks_on_list': u'12'},
#   u"CAT'S EYE": {u'asin': None,
#    u'author': u' Margaret Atwood.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'7'},
#   u'MIDNIGHT': {u'asin': None,
#    u'author': u' Dean R. Koontz.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'10'},
#   u'MORNING GLORY': {u'asin': None,
#    u'author': u' LaVyrle Spencer.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'13',
#    u'rank_this_wk': u'13',
#    u'wks_on_list': u'2'},
#   u'RAINBOW IN THE MIST': {u'asin': None,
#    u'author': u' Phyllis A. Whitney.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'14',
#    u'wks_on_list': u'1'},
#   u'RIVALS': {u'asin': None,
#    u'author': u' Janet Dailey.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'14',
#    u'rank_this_wk': u'15',
#    u'wks_on_list': u'11'},
#   u'STAR': {u'asin': None,
#    u'author': u' Danielle Steel.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'6'},
#   u'THE CARDINAL OF THE KREMLIN': {u'asin': None,
#    u'author': u' Tom Clancy.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'11',
#    u'rank_this_wk': u'11',
#    u'wks_on_list': u'35'},
#   u'THE EDGE': {u'asin': None,
#    u'author': u' Dick Francis.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'6'},
#   u'THE FORTUNE': {u'asin': None,
#    u'author': u' Michael Korda.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'8'},
#   u'THE LONG DARK TEA-TIME OF THE SOUL': {u'asin': None,
#    u'author': u' Douglas Adams.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'4'},
#   u'THE SANDS OF TIME': {u'asin': None,
#    u'author': u' Sidney Sheldon.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'20'},
#   u'THE SATANIC VERSES': {u'asin': None,
#    u'author': u' Salman Rushdie.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'1'}},
#  u'2005-03-06': {u'VANISHING ACTS': {u'asin': None,
#    u'author': u' Jodi Picoult.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'76',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'7'}},
#  u'1989-03-12': {u'A PRAYER FOR OWEN MEANY': {u'asin': None,
#    u'author': u' John Irving.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'1'},
#   u'A SEASON IN HELL': {u'asin': None,
#    u'author': u' Jack Higgins.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'14',
#    u'rank_this_wk': u'17',
#    u'wks_on_list': u'10'},
#   u'BILLY BATHGATE': {u'asin': None,
#    u'author': u' E. L. Doctorow.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'4'},
#   u'BLACK SAND': {u'asin': None,
#    u'author': u' William J. Caunitz.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'13',
#    u'rank_this_wk': u'16',
#    u'wks_on_list': u'2'},
#   u'BREATHING LESSONS': {u'asin': None,
#    u'author': u' Anne Tyler.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'11',
#    u'rank_this_wk': u'15',
#    u'wks_on_list': u'26'},
#   u"CAT'S EYE": {u'asin': None,
#    u'author': u' Margaret Atwood.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'5'},
#   u'MIDNIGHT': {u'asin': None,
#    u'author': u' Dean R. Koontz.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'9'},
#   u'MORNING GLORY': {u'asin': None,
#    u'author': u' LaVyrle Spencer.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'13',
#    u'wks_on_list': u'1'},
#   u'MUTATION': {u'asin': None,
#    u'author': u' Robin Cook.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'15',
#    u'rank_this_wk': u'12',
#    u'wks_on_list': u'9'},
#   u'RIVALS': {u'asin': None,
#    u'author': u' Janet Dailey.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'12',
#    u'rank_this_wk': u'14',
#    u'wks_on_list': u'10'},
#   u'STAR': {u'asin': None,
#    u'author': u' Danielle Steel.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'5'},
#   u'THE CARDINAL OF THE KREMLIN': {u'asin': None,
#    u'author': u' Tom Clancy.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'11',
#    u'wks_on_list': u'34'},
#   u'THE EDGE': {u'asin': None,
#    u'author': u' Dick Francis.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'5'},
#   u'THE FORTUNE': {u'asin': None,
#    u'author': u' Michael Korda.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'5'},
#   u'THE LONG DARK TEA-TIME OF THE SOUL': {u'asin': None,
#    u'author': u' Douglas Adams.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'3'},
#   u'THE SANDS OF TIME': {u'asin': None,
#    u'author': u' Sidney Sheldon.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'19'},
#   u'THE SATANIC VERSES': {u'asin': None,
#    u'author': u' Salman Rushdie.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'4'}},
#  u'1983-07-31': {u'ASCENT INTO HELL': {u'asin': None,
#    u'author': u' Andrew M. Greeley.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'11',
#    u'rank_this_wk': u'12',
#    u'wks_on_list': u'11'},
#   u'AUGUST': {u'asin': None,
#    u'author': u' Judith Rossner.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'1'},
#   u'CHRISTINE': {u'asin': None,
#    u'author': u' Stephen King.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'19'},
#   u'GODPLAYER': {u'asin': None,
#    u'author': u' Robin Cook.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'6'},
#   u'HEARTBURN': {u'asin': None,
#    u'author': u' Nora Ephron.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'16'},
#   u'HOLLYWOOD WIVES': {u'asin': None,
#    u'author': u' Jackie Collins.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'2'},
#   u'RETURN OF THE JEDI': {u'asin': None,
#    u'author': u'adapted  Joan D. Vinge.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'10'},
#   u'THE LITTLE DRUMMER GIRL': {u'asin': None,
#    u'author': u' John le Carr\xe9.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'3',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'22'},
#   u'THE LONESOME GODS': {u'asin': None,
#    u'author': u" Louis L'Amour.",
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'15',
#    u'wks_on_list': u'19'},
#   u'THE NAME OF THE ROSE': {u'asin': None,
#    u'author': u' Umberto Eco.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'8'},
#   u'THE SEDUCTION OF PETER S.': {u'asin': None,
#    u'author': u' Lawrence Sanders.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'4'},
#   u'THE SUMMER OF KATYA': {u'asin': None,
#    u'author': u' Trevanian.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'9',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'14'},
#   u'THE WORLD IS MADE OF GLASS': {u'asin': None,
#    u'author': u' Morris West.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'13',
#    u'rank_this_wk': u'13',
#    u'wks_on_list': u'3'},
#   u'VOICE OF THE HEART': {u'asin': None,
#    u'author': u' Barbara Taylor Bradford.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'12',
#    u'rank_this_wk': u'14',
#    u'wks_on_list': u'20'},
#   u'WHITE GOLD WIELDER': {u'asin': None,
#    u'author': u' Stephen R. Donaldson.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'11',
#    u'wks_on_list': u'19'}},
#  u'1998-08-30': {u'MESSAGE IN A BOTTLE': {u'asin': None,
#    u'author': u' Nicholas Sparks.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'21'}},
#  u'2008-03-30': {u'7TH HEAVEN': {u'asin': None,
#    u'author': u' James Patterson and Maxine Paetro.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'7',
#    u'wks_on_list': u'8'},
#   u'A PRISONER OF BIRTH': {u'asin': None,
#    u'author': u' Jeffrey Archer.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'6',
#    u'rank_this_wk': u'8',
#    u'wks_on_list': u'4'},
#   u'A THOUSAND SPLENDID SUNS': {u'asin': None,
#    u'author': u' Khaled Hosseini.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'7',
#    u'rank_this_wk': u'9',
#    u'wks_on_list': u'45'},
#   u'BLACK WIDOW': {u'asin': None,
#    u'author': u' Randy Wayne White.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'10',
#    u'rank_this_wk': u'11',
#    u'wks_on_list': u'2'},
#   u'BLUE-EYED DEVIL': {u'asin': None,
#    u'author': u' Lisa Kleypas.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'14',
#    u'wks_on_list': u'1'},
#   u'BUCKINGHAM PALACE GARDENS': {u'asin': None,
#    u'author': u' Anne Perry.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'15',
#    u'wks_on_list': u'1'},
#   u'CHANGE OF HEART': {u'asin': None,
#    u'author': u' Jodi Picoult.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'1',
#    u'rank_this_wk': u'3',
#    u'wks_on_list': u'4'},
#   u'COMPULSION': {u'asin': None,
#    u'author': u' Jonathan Kellerman.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'1',
#    u'wks_on_list': u'1'},
#   u'DEAD HEAT': {u'asin': None,
#    u'author': u' Joel C. Rosenberg.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'4',
#    u'rank_this_wk': u'6',
#    u'wks_on_list': u'2'},
#   u'HOLLYWOOD CROWS': {u'asin': None,
#    u'author': u' Joseph Wambaugh.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'5',
#    u'wks_on_list': u'1'},
#   u'LOST SOULS': {u'asin': None,
#    u'author': u' Lisa Jackson.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'13',
#    u'wks_on_list': u'1'},
#   u'LUSH LIFE': {u'asin': None,
#    u'author': u' Richard Price.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'8',
#    u'rank_this_wk': u'10',
#    u'wks_on_list': u'4'},
#   u'REMEMBER ME?': {u'asin': None,
#    u'author': u' Sophie Kinsella.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'5',
#    u'rank_this_wk': u'4',
#    u'wks_on_list': u'4'},
#   u'THE APPEAL': {u'asin': None,
#    u'author': u' John Grisham.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'2',
#    u'rank_this_wk': u'2',
#    u'wks_on_list': u'9'},
#   u'WORLD WITHOUT END': {u'asin': None,
#    u'author': u' Ken Follett.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'13',
#    u'rank_this_wk': u'12',
#    u'wks_on_list': u'25'},
#   u'WRATH OF A MAD GOD': {u'asin': None,
#    u'author': u' Raymond E. Feist.',
#    u'isbn10': None,
#    u'isbn13': None,
#    u'rank_last_wk': u'0',
#    u'rank_this_wk': u'16',
#    u'wks_on_list': u'1'}},
#  ...}

# %%
flat_format_2_data = []
for list_date, lst in scraped_books_format2.iteritems():
#     print lst
    if lst == 'No list on this date':
        continue
    else:
        for title, meta in lst.iteritems():
            d = meta.copy()
            d['title'] = title
            d['list_date'] = list_date
            flat_format_2_data.append(d)

# %%
scraped_format2_df = pd.DataFrame(flat_format_2_data)

# %%
scraped_format2_df['title'].replace(to_replace='9 Other Top-ranking NATO Generals and Advisors.', 
                                    value = 'THE THIRD WORLD WAR: August 1985', inplace = True)

# %%
scraped_format2_df['author'].replace(to_replace = '9 Other Top-ranking NATO Generals and Advisors.', 
# 17756                         Anais Nin.**DELTA OF VENUS
# 17757            John le Carré.**THE HONORABLE SCHOOLBOY
# 17758                  Marilyn French.**THE WOMEN'S ROOM
# 17759                           Judith Krantz.**SCRUPLES
# 17760               Colleen McCullough.**THE THORN BIRDS
# 17761                 Joseph Wambaugh.**THE BLACK MARBLE
# 17762                             Irwin Shaw.**BEGGARMAN
# 17763                    E. L. Doctorow.**BILLY BATHGATE
# 17764                        Margaret Atwood.**CAT'S EYE
# 17765           Tom Clancy.**THE CARDINAL OF THE KREMLIN
# 17766                Salman Rushdie.**THE SATANIC VERSES
# 17767                 Payne Harrison.**STORMING INTREPID
# 17768                    Jack Higgins.**A SEASON IN HELL
# 17769                          Dean R. Koontz.**MIDNIGHT
# 17770                            Dick Francis.**THE EDGE
# 17771                              Janet Dailey.**RIVALS
# 17772                 Sidney Sheldon.**THE SANDS OF TIME
# 17773                              Robin Cook.**MUTATION
# 17774                              Danielle Steel.**STAR
# 17775                     Anne Tyler.**BREATHING LESSONS
# 17776                        Michael Korda.**THE FORTUNE
# 17777             Robertson Davies.**THE LYRE OF ORPHEUS
#
# [17778 rows x 10 columns]

# %%
books_to_get_isbns = scraped_format2_df.author_title.unique()

# %%
books_to_get_isbns
# Out:
# array([ 'General Sir John Hackett and Other Top-ranking NATO Generals and Advisors.**THE THIRD WORLD WAR: August 1985',
#        u' Robin Cook.**SPHINX', u' Peter Straub.**GHOST STORY',
#        u' Joseph Heller.**GOOD AS GOLD',
#        u' James A. Michener.**CHESAPEAKE',
#        u' Herman Wouk.**WAR AND REMEMBRANCE', u' Len Deighton.**SS-GB',
#        u' Walter F. Murphy.**THE VICAR OF CHRIST', u' Trevanian.**SHIBUMI',
#        u" Richard Bach.**THERE'S NO SUCH PLACE AS FAR AWAY"], dtype=object)

# %%
get_isbns_asins(books_to_get_isbns[:1000])

# %%
get_isbns_asins(books_to_get_isbns[1000:2000])

# %%
get_isbns_asins(books_to_get_isbns[2000:])

# %%
isbns = pd.read_json('data/format2_books_with_isbns.json').T

# %%
isbns.reset_index(inplace = True)

# %%
isbns
# Out:
#                                                 index        asin      isbn10  \
# 0                      Dale Brown**DAY OF THE CHEETAH  B00IT7GKF0  0425120430
# 1                               Danielle Steel**DADDY  B001TLZF8Q  9953299005
# 2                   Helen MacInnes**PRELUDE TO TERROR  B00F1W07XM  0449213781
# 3                          Jack Higgins**COLD HARBOUR  B000OIZV4I  0425193209
# 4                        James A. Michener**CARIBBEAN  B00FO60AZA  0812974921
# 5            Jimmy Buffett**TALES FROM MARGARITAVILLE              0156026988
# 6                    Judith Michael**A RULING PASSION              0671899589
# 7                              Len Deighton**SPY LINE  B003Z6QGJK  0345420179
# 8                               Peter Straub**MYSTERY  B000FC1CK0  0375756701
# 9                    Phillip Margolin**PROOF POSITIVE  B000GCFWXC  0060735058
# 10                         Robin Cook**HARMFUL INTENT  B000OCXIUI  0425125467
# 11                    Sara Gruen**WATER FOR ELEPHANTS  B003I1WY2A  1565125606
# 12                        Stephen King**THE DARK HALF  B018ER7L7U  045052468X
# 13                        Thomas Harris**BLACK SUNDAY  B002DMZ9U4  0451217411
# 14                           Thomas Pynchon**VINELAND  B005CRQ2DU  3499136287
# 15               Tom Clancy**CLEAR AND PRESENT DANGER  B001QEAQQ2  0425144372
# 16                   Umberto Eco**FOUCAULT'S PENDULUM  B003WUYPI8  015603297X
# 17                  William F. Buckley Jr.**HIGH JINX  B0116EBXNQ  1888952520
# 18              William F. Buckley Jr.**STAINED GLASS  B0116EBXNG  1888952296
# 19             William F. Buckley Jr.**WHO'S ON FIRST  B0116EBXO0  1888952288
# 20                          **THE GREAT TRAIN ROBBERY  B007UH4DD6  0553129198
# 21                              Jr.**SAVING THE QUEEN              0446891649
# 22  THE BAD PLACE  Dean R. Koontz**THE BAD PLACE b...  B001RHOJTI  0425195481
#
#            isbn13
# 0   9780425120439
# 1   9789953299006
# 2   9780449213780
# 3   9780425193204
# 4   9780812974928
# 5   9780156026987
# 6   9780671899585
# 7   9780345420176
# 8   9780375756702
# 9   9780060735050
# 10  9780425125465
# 11  9781565125605
# 12  9780450524684
# 13  9780451217417
# 14  9783499136283
# 15  9780425144374
# 16  9780156032971
# 17  9781888952520
# 18  9781888952292
# 19  9781888952285
# 20  9780553129199
# 21  9780446891646
# 22  9780425195482

# %%
isbns2 = pd.read_json('data/format2_books_with_isbns_part2.json').T

# %%
isbns2.reset_index(inplace=True)

# %%
isbns2
# Out:
#                                               index        asin      isbn10  \
# 0                      Dan Brown**THE DA VINCI CODE  B000FA675C  0307277674
# 1                William F. Buckley Jr.**MARCO POLO  B0116EBXP4  1888952113
# 2   William F. Buckley Jr.**SEE YOU LATER ALLIGATOR              1581825374
# 3    William F. Buckley Jr.**THE STORY OF HENRI TOD              1888952121
# 4                                      **THE CLINIC  B000FBFN92  0553712802
# 5                          1 Gates Jr.**1 Gates Jr.              9780393059
# 6                                            27**27              0615974058
# 7                                            33**33  B000O76O8G  1591841038
# 8                              MacDonald**MacDonald              0064401480
#
#           isbn13
# 0  9780307277671
# 1  9781888952117
# 2  9781581825374
# 3  9781888952124
# 4  9780553712803
# 5
# 6  9780615974057
# 7  9781591841036
# 8  9780064401487

# %%
isbns3 = pd.read_json('data/format2_books_with_isbns_part3.json').T

# %%
isbns3.reset_index(inplace = True)

# %%
isbns3
# Out:
#                                       index        asin      isbn10  \
# 0               Annie Dillard**THE MAYTREES  B000ROKXZ6  0061239534
# 1            Graeme Base**THE ELEVENTH HOUR              0810932652
# 2            Julian Barnes**ARTHUR & GEORGE  B01E8XKCY8  1400097037
# 3           Pat Conroy**THE PRINCE OF TIDES  B003XKN65K  0553381547
# 4   William F. Buckley Jr.**MONGOOSE R.I.P.  B0116EBXLI  0440202310
# 5                    **THE THIRD DEADLY SIN  B00B4V7T0I  042510429X
#
#           isbn13
# 0  9780061239533
# 1  9780810932654
# 2  9781400097036
# 3  9780553381542
# 4  9780440202318
# 5  9780425104293

# %%
isbns_1974_2008 = pd.concat((isbns, isbns2, isbns3), axis = 0, ignore_index=True)

# 7   9780345420176
# 8   9780375756702
# 9   9780060735050
# 10  9780425125465
# 11  9781565125605
# 12  9780450524684
# 13  9780451217417
# 14  9783499136283
# 15  9780425144374
# 16  9780156032971
# 17  9781888952520
# 18  9781888952292
# 19  9781888952285
# 20  9780553129199
# 21  9780446891646
# 22  9780425195482
# 23  9780307277671
# 24  9781888952117
# 25  9781581825374
# 26  9781888952124
# 27  9780553712803
# 28
# 29  9780615974057
# 30  9781591841036
# 31  9780064401487
# 32  9780061239533
# 33  9780810932654
# 34  9781400097036
# 35  9780553381542
# 36  9780440202318
# 37  9780425104293

# %%
books_1974_2008 = pd.merge(scraped_format2_df, isbns_1974_2008, how = 'left', on = 'author_title')

# %%
pd.merge?

# %%
books_1974_2008.drop(['asin_x', 'isbn10_x', 'isbn13_x'], axis = 1, inplace = True)

# %%
books_1974_2008.rename(columns = lambda x: x.replace('_y', ''), inplace = True)

# %%
isbns_still_missing = books_1974_2008[books_1974_2008.isbn13.isnull()]

# %%
isbns_needed = isbns_still_missing.author_title.unique()

# %%
isbns_found1, isbns_still_missing1 = get_isbns_google(isbns_needed)

# %%
google_isbns_found = pd.DataFrame(isbns_found1).T

# %%
google_isbns_found.reset_index(inplace = True)

# %%
google_isbns_found.rename(columns = lambda x: x.replace('index', 'author_title'), inplace = True)

# %%
google_isbns_found.to_csv('data/google_isbns_1974_to_2008.tsv', sep = '\t', encoding = 'utf-8')

# %%
len(isbns_still_missing1)
# Out:
# 323

# %%
books_1974_2008
# Out:
#                                                   author   list_date  \
# 0      General Sir John Hackett and Other Top-ranking...  1979-06-24
# 1                                            Robin Cook.  1979-06-24
# 2                                          Peter Straub.  1979-06-24
# 3                                         Joseph Heller.  1979-06-24
# 4                                     James A. Michener.  1979-06-24
# 5                                           Herman Wouk.  1979-06-24
# 6                                          Len Deighton.  1979-06-24
# 7                                      Walter F. Murphy.  1979-06-24
# 8                                             Trevanian.  1979-06-24
# 9                                          Richard Bach.  1979-06-24
# 10                                        Robert Ludlum.  1979-06-24
# 11                                      Ruth Beebe Hill.  1979-06-24
# 12                                       William Styron.  1979-06-24
# 13                                       Peter Benchley.  1979-06-24
# 14                                           Rona Jaffe.  1979-06-24
# 15                                         Wilbur Smith.  1994-03-27
# 16                                      LaVyrle Spencer.  1994-03-20
# 17                                         Jack Higgins.  1997-07-13
# 18                                       Nelson DeMille.  1997-07-13
# 19                                         Sandra Brown.  1997-07-13
# 20                              Barbara Taylor Bradford.  1997-07-13
# 21                                      Charles Frazier.  1997-07-13
# 22                                           Dale Brown.  1997-07-13
# 23                                    Catherine Coulter.  1997-07-13
# 24                                       Danielle Steel.  1997-07-13
# 25                                    Edward Rutherfurd.  1997-07-13
# 26                                   Mary Higgins Clark.  1997-07-13
# 27                                      Nicholas Sparks.  1997-07-13
# 28                                          Peter Mayle.  1997-07-13
# 29                                  Anne Rivers Siddons.  1997-07-13
# ...                                                  ...         ...
# 17748                                      Richard Bach.  1978-03-05
# 17749                                    Sidney Sheldon.  1978-03-05
# 17753          24              Terence H. White.**THE BOOK OF MERLYN  NaN
# 17754          15                        Robert S. Elegant.**DYNASTY  NaN
# 17755          25                        John Fowles.**DANIEL MARTIN  NaN
# 17756          32                         Anais Nin.**DELTA OF VENUS  NaN
# 17757          24            John le Carré.**THE HONORABLE SCHOOLBOY  NaN
# 17758          15                  Marilyn French.**THE WOMEN'S ROOM  NaN
# 17759           2                           Judith Krantz.**SCRUPLES  NaN
# 17760          44               Colleen McCullough.**THE THORN BIRDS  NaN
# 17761          12                 Joseph Wambaugh.**THE BLACK MARBLE  NaN
# 17762          22                             Irwin Shaw.**BEGGARMAN  NaN
# 17763           1                    E. L. Doctorow.**BILLY BATHGATE  NaN
# 17764           3                        Margaret Atwood.**CAT'S EYE  NaN
# 17765          31           Tom Clancy.**THE CARDINAL OF THE KREMLIN  NaN
# 17766           1                Salman Rushdie.**THE SATANIC VERSES  NaN
# 17767           2                 Payne Harrison.**STORMING INTREPID  NaN
# 17768           7                    Jack Higgins.**A SEASON IN HELL  NaN
# 17769           6                          Dean R. Koontz.**MIDNIGHT  NaN
# 17770           2                            Dick Francis.**THE EDGE  NaN
# 17771           7                              Janet Dailey.**RIVALS  NaN
# 17772          16                 Sidney Sheldon.**THE SANDS OF TIME  NaN
# 17773           6                              Robin Cook.**MUTATION  NaN
# 17774           2                              Danielle Steel.**STAR  NaN
# 17775          24                     Anne Tyler.**BREATHING LESSONS  NaN
# 17776           2                        Michael Korda.**THE FORTUNE  NaN
# 17777           8             Robertson Davies.**THE LYRE OF ORPHEUS  NaN
#
#       isbn10 isbn13
# 0        NaN    NaN
# 1        NaN    NaN
# 2        NaN    NaN
# 3        NaN    NaN
# 4        NaN    NaN
# 5        NaN    NaN
# 6        NaN    NaN
# 7        NaN    NaN
# 8        NaN    NaN
# 9        NaN    NaN
# 10       NaN    NaN
# 11       NaN    NaN
# 12       NaN    NaN
# 13       NaN    NaN
# 14       NaN    NaN
# 15       NaN    NaN
# 16       NaN    NaN
# 17       NaN    NaN
# 18       NaN    NaN
# 19       NaN    NaN
# 20       NaN    NaN
# 21       NaN    NaN
# 22       NaN    NaN
# 23       NaN    NaN
# 24       NaN    NaN
# 25       NaN    NaN
# 26       NaN    NaN
# 27       NaN    NaN
# 28       NaN    NaN
# 29       NaN    NaN
# ...      ...    ...
# 17748    NaN    NaN
# 17749    NaN    NaN
# 17750    NaN    NaN
# 17751    NaN    NaN
# 17752    NaN    NaN
# 17753    NaN    NaN
# 17754    NaN    NaN
# 17755    NaN    NaN
# 17756    NaN    NaN
# 17757    NaN    NaN
# 17758    NaN    NaN
# 17759    NaN    NaN
# 17760    NaN    NaN
# 17761    NaN    NaN
# 17762    NaN    NaN
# 17763    NaN    NaN
# 17764    NaN    NaN
# 17765    NaN    NaN
# 17766    NaN    NaN
# 17767    NaN    NaN
# 17768    NaN    NaN
# 17769    NaN    NaN
# 17770    NaN    NaN
# 17771    NaN    NaN
# 17772    NaN    NaN
# 17773    NaN    NaN
# 17774    NaN    NaN
# 17775    NaN    NaN
# 17776    NaN    NaN
# 17777    NaN    NaN
#
# [17778 rows x 10 columns]
